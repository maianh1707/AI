# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-326-gec331cbd Python-3.10.12 torch-2.3.0+cu121 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.3/107.7 GB disk)

# %%
# !python /content/drive/MyDrive/yolov5/train.py --img 640 --batch 2 --epochs 3 --data /content/drive/MyDrive/yolov5/data/custom_data3.yaml --weights yolov5s.pt --cache
# Out:
# 2024-06-20 16:43:16.554284: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-20 16:43:16.554350: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-20 16:43:16.556572: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python detect.py --weights /content/drive/MyDrive/yolov5/runs/train/exp7/weights/last.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/Download.mp4
# Out:
# detect: weights=['/content/drive/MyDrive/yolov5/runs/train/exp7/weights/last.pt'], source=/content/drive/MyDrive/Download.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-326-gec331cbd Python-3.10.12 torch-2.3.0+cu121 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/992) /content/drive/MyDrive/Download.mp4: 640x384 (no detections), 262.3ms
# video 1/1 (2/992) /content/drive/MyDrive/Download.mp4: 640x384 (no detections), 229.8ms
# video 1/1 (3/992) /content/drive/MyDrive/Download.mp4: 640x384 (no detections), 215.2ms
# ...
